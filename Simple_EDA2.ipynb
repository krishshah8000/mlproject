# %% [markdown]
# <a href="https://colab.research.google.com/github/krishshah8000/mlproject/blob/master/Simple_EDA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/CS-4Clear_Mountain_Student_Survey.csv")

# %%
df.head()
# Out:
#    Gender Class Standing  Age  Hours Studied    Employment  Commute Time (Min)
# 0    Male      Sophomore   20             15     Part-time                  25
# 1  Female         Junior   21             10  Not Employed                  10
# 2    Male         Senior   22             12     Full-time                  35
# 3  Female       Freshman   18             20     Part-time                  15
# 4  Female      Sophomore   19             14     Full-time                  30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gender              50 non-null     object
#  1   Class Standing      50 non-null     object
#  2   Age                 50 non-null     int64
#  3   Hours Studied       50 non-null     int64
#  4   Employment          50 non-null     object
#  5   Commute Time (Min)  50 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
#              Age  Hours Studied  Commute Time (Min)
# count  50.000000      50.000000           50.000000
# mean   20.400000      13.800000           22.500000
# std     1.641304       3.374575            9.910312
# min    18.000000       9.000000           10.000000
# 25%    19.000000      11.000000           15.000000
# 50%    20.500000      13.500000           22.500000
# 75%    22.000000      16.000000           30.000000
# max    23.000000      20.000000           40.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Hours Studied'].plot(kind='hist', bins=20, title='Hours Studied')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = sb.load_dataset("titanic")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sb.histplot(df['age'], kde = True)
plt.title("Age Distribution")
plt.show()

# %%
df.age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.boxplot(column='age')
plt.title("Age Distriibution Boxplot")
plt.show()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sb.countplot(x='class',data=df)
plt.title("passenger Class Ditribution")
plt.show()

# %%
sb.countplot(x='sex',data=df)
plt.title("Gnder Ditribution")
plt.show()

# %%
sb.countplot(x='sex', hue='survived',data=df)
plt.title("Gnder Ditribution")
plt.show()

# %%
sb.histplot(x='age', hue='survived',data=df)
plt.title("Gnder Ditribution")
plt.show()
